# %% [markdown]
# # Approval-bound production collection
#
# This notebook is an orchestration and audit view; logic lives in `src/p4`.

# %%
# Network execution intentionally absent.
# Use p4 collect only after a separate approval.
